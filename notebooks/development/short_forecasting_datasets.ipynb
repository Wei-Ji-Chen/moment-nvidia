# %% [markdown]
# ### Short-forecasting datasets

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

from moment.common import PATHS
from moment.data.load_data import convert_tsf_to_dataframe
from moment.data.forecasting_datasets import get_forecasting_datasets, ShortForecastingDataset

# %%
forecasting_datasets = get_forecasting_datasets(collection="monash")
print(f"Number of forecasting datasets:", len(forecasting_datasets))
# Out:
# Number of forecasting datasets: 47

# %%
forecasting_datasets[:5]
# Out:
# ['/XXXX-14/project/public/XXXX-9/TimeseriesDatasets/forecasting/monash/m4_daily_dataset.tsf',
#  '/XXXX-14/project/public/XXXX-9/TimeseriesDatasets/forecasting/monash/dominick_dataset.tsf',
#  '/XXXX-14/project/public/XXXX-9/TimeseriesDatasets/forecasting/monash/nn5_weekly_dataset.tsf',
#  '/XXXX-14/project/public/XXXX-9/TimeseriesDatasets/forecasting/monash/weather_dataset.tsf',
#  '/XXXX-14/project/public/XXXX-9/TimeseriesDatasets/forecasting/monash/m1_yearly_dataset.tsf']

# %%
dataset = ShortForecastingDataset(
    full_file_path_and_name = '/XXXX-14/project/public/XXXX-9/TimeseriesDatasets/forecasting/monash/nn5_weekly_dataset.tsf',
    data_split = 'test', scale  = True, task = 'pre-training', train_ratio = 0.6, 
    val_ratio = 0.1, test_ratio  = 0.3, random_seed  = 42, downsampling_type='random')
# Out:
# weekly
# 8
# False
# True
# ----------------------------------------------------------------------------------------------------
# Dataset: nn5_weekly_dataset
# df len: 111
#   series_name start_timestamp  \
# 0          T1      1996-03-18
# 1          T2      1996-03-18
# 2          T3      1996-03-18
# 3          T4      1996-03-18
# 4          T5      1996-03-18
#
#                                         series_value
# 0  [141.964285714286, 160.714285714286, 165.30015...
# 1  [90.9155328798185, 126.658163265306, 117.44614...
# 2  [119.203514739229, 138.718820861678, 115.98639...
# 3  [96.8537414965986, 136.975623582766, 132.56802...
# 4  [130.796485260771, 113.43537414966, 121.720226...

# %%
dataset
# Out:
# ShortForecastingDataset(dataset_name=nn5_weekly_dataset,length_dataset=33,seq_len=512,pred_len=8,data_split=test,scale=True,task_name=forecasting,n_channels=1,train_ratio=0.6,val_ratio=0.1,test_ratio=0.3,

# %%
dataset.data.shape
# Out:
# (33, 3)

# %%
dataset.data.shape
# Out:
# (33, 3)

# %%
dataset.data.shape
# Out:
# (33, 3)

# %%
idx = np.random.randint(0, len(dataset))
dataset.plot(idx)
